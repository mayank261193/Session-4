# %% [markdown]
# # Session 4 Practice — OOP & Tooling
# **Python for Data Analytics Bootcamp**
#
# Solve each exercise in the code cell below it. Check your work against the matching Solutions notebook when done.

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 1 — Define a class
#
# Create a class named `Car` that stores three attributes set in its `__init__` method: `make`, `model`, and `year`. No other methods are needed yet.
#
# For example, `Car("Toyota", "Corolla", 2021)` should create a car whose `make` is `"Toyota"`, `model` is `"Corolla"`, and `year` is `2021`.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 2 — Create objects and print attributes
#
# Define a `Planet` class with two attributes, `name` and `number_of_moons`. Create three Planet objects — Earth (1 moon), Mars (2 moons), and Jupiter (95 moons) — and print each planet's name alongside its number of moons.
#
# Expected output:
# ```
# Earth has 1 moon(s)
# Mars has 2 moon(s)
# Jupiter has 95 moon(s)
# ```

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 3 — A method that returns formatted info
#
# Create a `Movie` class with attributes `title`, `director`, and `year`. Add a method called `details()` that **returns** (does not print) a single formatted string. Create one Movie object and print the result of calling `details()`.
#
# Expected output:
# ```
# 'Inception' was directed by Christopher Nolan in 2010.
# ```

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 4 — A method that updates an attribute
#
# Create a `SavingsAccount` class with attributes `owner` and `balance`. Add a method `deposit(amount)` that increases the balance by the given amount. Open an account for `"Neha"` with a balance of `5000`, deposit `1500`, then print the updated balance.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 5 — Convert a dictionary into a class
#
# The snippet below stores a laptop as a dictionary:
#
# ```python
# laptop = {
#     "brand": "Dell",
#     "ram_gb": 16,
#     "price": 72000,
# }
# ```
#
# Rewrite this as an equivalent class named `Laptop`. The `__init__` should set `brand`, `ram_gb`, and `price`, and add a method `specs()` that returns a formatted summary string. Create a Laptop object with the same values and print its specs.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 6 — Install a single package with pip
#
# In a terminal, how would you install a single package called `requests` using pip? Write the command as a comment so this cell runs without errors.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 7 — Install several packages at once
#
# Write the single pip command that installs three packages together in one line: `numpy`, `pandas`, and `matplotlib`.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 8 — Freeze and restore an environment
#
# Write the command that saves every installed package (with its version) into a file named `requirements.txt`. Then write the command that installs all packages listed in that file.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 9 — Create and activate a virtual environment (Windows)
#
# On Windows, write the commands to (a) create a virtual environment named `venv`, and (b) activate it.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 10 — Jupyter basics
#
# Answer these three short questions as comments:
#
# 1. Which keyboard shortcut runs the current cell and moves to the next one?
# 2. What is the difference between a Markdown cell and a Code cell?
# 3. What happens to your variables when you choose "Restart Kernel"?

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 11 — Start tracking a project with Git
#
# You have a new project folder. Write the Git commands to (a) initialize a repository, (b) stage all files, and (c) make a first commit with the message `Initial commit`.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 12 — Push your code to a remote
#
# Your local repository is ready and you have created an empty repository on GitHub. Write the commands to (a) connect your local repo to the remote URL, and (b) push your commits to the `main` branch.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 13 — Set up a new project end to end
#
# Put the workflow together. For a brand-new project folder on Windows, write the ordered commands to: create and activate a virtual environment named `venv`, install `pandas`, save the environment to `requirements.txt`, then initialize Git and make a first commit.

# %%
# Write your code here
