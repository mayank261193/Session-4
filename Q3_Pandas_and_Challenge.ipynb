# %% [markdown]
# # Session 4 Practice — Pandas & Combined Challenge
# **Python for Data Analytics Bootcamp**
#
# Solve each exercise in the code cell below it. Check your work against the matching Solutions notebook when done.

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 1 — A DataFrame from a dictionary
#
# Import pandas using its standard alias, then build a DataFrame from the dictionary below and display it:
#
# ```python
# {
#     "product": ["Pen", "Notebook", "Eraser", "Marker"],
#     "price": [10, 55, 8, 40],
#     "in_stock": [120, 80, 200, 45],
# }
# ```

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 2 — Read a CSV file
#
# Read the file `students.csv` (located in the same folder as this notebook) into a DataFrame named `students`, and display the first five rows.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 3 — Shape and column names
#
# Using the `students` DataFrame, print the number of rows and columns (its shape) and the list of column names.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 4 — Summaries with info() and describe()
#
# Display a concise technical summary of the `students` DataFrame using `info()`, and the summary statistics of its numeric columns using `describe()`.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 5 — Select a single column
#
# Select and display only the `math_score` column from the `students` DataFrame.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 6 — Select multiple columns
#
# Select and display two columns together — `name` and `city` — from the `students` DataFrame.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 7 — Filter rows by a number
#
# Display only the students whose `attendance` is greater than 90.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 8 — Filter rows by text
#
# Display only the students who live in `Pune`.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 9 — Average of a column
#
# Calculate and print the average (mean) `math_score` of all students, rounded to one decimal place.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 10 — Highest and lowest values
#
# Print the highest and the lowest `science_score` in the `students` DataFrame.

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 11 — Challenge — build objects and collect their data
#
# Define an `Employee` class with attributes `name`, `department`, and `salary`. Create four Employee objects with different values, then collect their data into a list of dictionaries (one dictionary per employee).

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 12 — Challenge — turn objects into a DataFrame
#
# Convert the list of employee dictionaries from the previous exercise into a pandas DataFrame and display it. Then print the average salary across all four employees.

# %%
# Write your code here
